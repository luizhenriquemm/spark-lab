# %%
# %run ../spark-default.py

# %%
spark.conf.set("spark.sql.sources.partitionOverwriteMode","dynamic")

# %%
import builtins as b
from datetime import datetime, timedelta, date
import sys, traceback
from delta.tables import DeltaTable

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# spark.sql("optimize stage.ciha_step1")

# %%
# Até aqui, a base do CIHA foi enriquecida com:
#  - Nome das cidades (residencia e movimentação)
#  - Nome, uf e info dos estados (residencia e movimentação)
#  - Infos do IBGE como população e área
#  - Calculo de feriados

# %%
ciha_step1 = spark.table("stage.ciha_step1")
ciha_step1.printSchema()
# Out:
# root
#  |-- pk: string (nullable = true)
#  |-- mes_cmpt: string (nullable = true)
#  |-- espec: string (nullable = true)
#  |-- cgc_hosp: string (nullable = true)
#  |-- munic_res: string (nullable = true)
#  |-- nasc: date (nullable = true)
#  |-- sexo: string (nullable = true)
#  |-- uti_mes_to: string (nullable = true)
#  |-- uti_int_to: string (nullable = true)
#  |-- proc_rea: string (nullable = true)
#  |-- qt_proc: string (nullable = true)
#  |-- dt_atend: date (nullable = true)
#  |-- dt_saida: date (nullable = true)
#  |-- diag_princ: string (nullable = true)
#  |-- diag_secun: string (nullable = true)
#  |-- cobranca: string (nullable = true)
#  |-- natureza: string (nullable = true)
#  |-- gestao: string (nullable = true)
#  |-- munic_mov: string (nullable = true)
#  |-- cod_idade: string (nullable = true)
#  |-- idade: string (nullable = true)
#  |-- dias_perm: string (nullable = true)
#  |-- morte: string (nullable = true)
#  |-- nacional: string (nullable = true)
#  |-- car_int: string (nullable = true)
#  |-- homonimo: string (nullable = true)
#  |-- cnes: string (nullable = true)
#  |-- fonte: string (nullable = true)
#  |-- cgc_consor: string (nullable = true)
#  |-- modalidade: string (nullable = true)
#  |-- input_file_name: string (nullable = true)
#  |-- arquivo_sigla_uf: string (nullable = true)
#  |-- ano_cmpt: integer (nullable = true)
#  |-- feriado: boolean (nullable = true)
#  |-- feriados: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- nome: string (nullable = true)
#  |    |    |-- tipo: string (nullable = true)
#  |    |    |-- descricao: string (nullable = true)
#  |    |    |-- uf: string (nullable = true)
#  |    |    |-- municipio: string (nullable = true)
#  |-- feriados_prox: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- data: string (nullable = true)
#  |    |    |-- nome: string (nullable = true)
#  |    |    |-- tipo: string (nullable = true)
#  |    |    |-- descricao: string (nullable = true)
#  |    |    |-- uf: string (nullable = true)
#  |    |    |-- municipio: string (nullable = true)
#  |-- feriados_prox_dist: integer (nullable = true)
#  |-- munic_res_nome_uf: string (nullable = true)
#  |-- munic_mov_nome_uf: string (nullable = true)
#  |-- munic_res_nome_municipio: string (nullable = true)
#  |-- munic_mov_nome_municipio: string (nullable = true)
#  |-- munic_res_sigla_uf: string (nullable = true)
#  |-- munic_mov_sigla_uf: string (nullable = true)
#  |-- munic_res_regiao: string (nullable = true)
#  |-- munic_mov_regiao: string (nullable = true)
#  |-- munic_res_populacao_residente: string (nullable = true)
#  |-- munic_mov_populacao_residente: string (nullable = true)
#  |-- munic_res_area_unidade_territorial: string (nullable = true)
#  |-- munic_mov_area_unidade_territorial: string (nullable = true)

# %%
ciha_step1
# Out:
# +--------------------+--------+-----+--------------+---------+----------+----+----------+----------+----------+-------+----------+----------+----------+----------+--------+--------+------+---------+---------+-----+---------+-----+--------+-------+--------+-------+-----+--------------+----------+--------------------+----------------+--------+-------+--------------------+--------------------+------------------+-----------------+-----------------+------------------------+------------------------+------------------+------------------+----------------+----------------+-----------------------------+-----------------------------+----------------------------------+----------------------------------+
# |                  pk|mes_cmpt|espec|      cgc_hosp|munic_res|      nasc|sexo|uti_mes_to|uti_int_to|  proc_rea|qt_proc|  dt_atend|  dt_saida|diag_princ|diag_secun|cobranca|natureza|gestao|munic_mov|cod_idade|idade|dias_perm|morte|nacional|car_int|homonimo|   cnes|fonte|    cgc_consor|modalidade|     input_file_name|arquivo_sigla_uf|ano_cmpt|feriado|            feriados|       feriados_prox|feriados_prox_dist|munic_res_nome_uf|munic_mov_nome_uf|munic_res_nome_municipio|munic_mov_nome_municipio|munic_res_sigla_uf|munic_mov_sigla_uf|munic_res_regiao|munic_mov_regiao|munic_res_populacao_residente|munic_mov_populacao_residente|munic_res_area_unidade_territorial|munic_mov_area_unidade_territorial|
# +--------------------+--------+-----+--------------+---------+----------+----+----------+----------+----------+-------+----------+----------+----------+----------+--------+--------+------+---------+---------+-----+---------+-----+--------+-------+--------+-------+-----+--------------+----------+--------------------+----------------+--------+-------+--------------------+--------------------+------------------+-----------------+-----------------+------------------------+------------------------+------------------+------------------+----------------+----------------+-----------------------------+-----------------------------+----------------------------------+----------------------------------+
# |00016e53-72d5-47a...|      08| null|60552098000111|   355030|1972-06-26|   3|         0|       000|0301010072|      2|2022-08-23|2022-08-23|      E039|      null|    null|    null|     M|   355030|        4|   50|        0|    0|    null|   null|    null|2082624|   01|             1|        01|s3a://datalake/so...|              SP|    2022|  false|                null|[{2022-07-26, Fun...|                15|        São Paulo|        São Paulo|               São Paulo|               São Paulo|                SP|                SP|         Sudeste|         Sudeste|                     11253503|                     11253503|                          1521.101|                          1521.101|
# |a6ad9b39-44dd-468...|      01| null|20959292000100|   313170|1992-01-14|   3|         0|       000|0301010072|      1|2022-01-19|2022-01-19|      R529|      null|      18|    null|     M|   313170|        4|   30|        0|    0|    null|   null|    null|2215586|   01|00000000000000|        01|s3a://datalake/so...|              MG|    2022|  false|                null|[{2021-12-25, Nat...|                18|     Minas Gerais|     Minas Gerais|                 Itabira|                 Itabira|                MG|                MG|         Sudeste|         Sudeste|                       109783|                       109783|                          1253.704|                          1253.704|
# |0001aa82-4139-476...|      04| null|61599908000158|   355030|1965-02-01|   1|         0|       000|0407010009|      2|2022-04-22|2022-04-22|      Z018|      null|    null|    null|     M|   355030|        4|   57|        0|    0|    null|   null|    null|2080575|   01|             1|        01|s3a://datalake/so...|              SP|    2022|  false|                null|[{2022-04-15, Sex...|                 1|        São Paulo|        São Paulo|               São Paulo|               São Paulo|                SP|                SP|         Sudeste|         Sudeste|                     11253503|                     11253503|                          1521.101|                          1521.101|
# |a6b09c4e-c80a-433...|      03| null|60975737008560|   355030|1965-03-01|   3|         0|       000|0301060061|      1|2022-03-31|2022-03-31|       Z00|      null|    null|    null|     M|   355030|        4|   57|        0|    0|    null|   null|    null|9406751|   01|             1|        01|s3a://datalake/so...|              SP|    2022|  false|                null|[{2022-04-15, Sex...|                15|        São Paulo|        São Paulo|               São Paulo|               São Paulo|                SP|                SP|         Sudeste|         Sudeste|                     11253503|                     11253503|                          1521.101|                          1521.101|
# |00031bdc-881a-4fd...|      09| null|09152345000135|   315120|1980-03-23|   3|         0|       000|0301060061|      1|2022-09-19|2022-09-19|      E669|      null|    null|    null|     M|   315120|        4|   42|        0|    0|    null|   null|    null|2119528|   01|             1|        01|s3a://datalake/so...|              MG|    2022|  false|                null|[{2022-10-12, Nos...|                12|     Minas Gerais|     Minas Gerais|                Pirapora|                Pirapora|                MG|                MG|         Sudeste|         Sudeste|                        53368|                        53368|                           549.514|                           549.514|
# |a6b189ba-f2b3-4a8...|      03| null|60194990000844|   310620|1944-06-27|   3|         0|       001|0408030003|      1|2022-03-23|2022-03-27|      M511|      null|      12|    null|     M|   310620|        4|   77|        4|    0|    null|   null|    null|2200422|   01|             1|        02|s3a://datalake/so...|              MG|    2022|  false|                null|[{2022-04-15, Sex...|                23|     Minas Gerais|     Minas Gerais|          Belo Horizonte|          Belo Horizonte|                MG|                MG|         Sudeste|         Sudeste|                      2375151|                      2375151|                           331.401|                           331.401|
# |0004b978-4ac7-4ab...|      11| null|10892164000124|   261160|1959-11-17|   3|         0|       000|0301060002|      1|2022-11-29|2022-11-29|      B342|      null|      18|    null|     D|   261160|        4|   63|        0|    0|    null|   null|    null|0001120|   01|00000000000000|        01|s3a://datalake/so...|              PE|    2022|  false|                null|[{2022-12-08, Dia...|                 9|       Pernambuco|       Pernambuco|                  Recife|                  Recife|                PE|                PE|        Nordeste|        Nordeste|                      1537704|                      1537704|                           218.435|                           218.435|
# |a6b1f954-05a9-4d9...|      04| null|15194004000125|   292740|1994-05-26|   3|         0|       000|0202010201|      1|2022-04-16|2022-04-16|      O141|      null|    null|    null|     M|   292740|        4|   27|        0|    0|    null|   null|    null|5407591|   01|             1|        01|s3a://datalake/so...|              BA|    2022|  false|                null|[{2022-04-15, Sex...|                 1|            Bahia|            Bahia|                Salvador|                Salvador|                BA|                BA|        Nordeste|        Nordeste|                      2675656|                      2675656|                           693.276|                           693.276|
# |0005c95b-2ef0-4eb...|      04| null|88630413000796|   431490|2007-02-20|   1|         0|       000|0501050035|      1|2022-04-04|2022-04-04|      M796|      null|    null|    null|     M|   431490|        4|   15|        0|    0|    null|   null|    null|2262568|   01|             1|        01|s3a://datalake/so...|              RS|    2022|  false|                null|[{2022-04-15, Sex...|                11|Rio Grande do Sul|Rio Grande do Sul|            Porto Alegre|            Porto Alegre|                RS|                RS|             Sul|             Sul|                      1409351|                      1409351|                           496.682|                           496.682|
# |a6b360d2-d98d-419...|      06| null|45775608000126|   350790|1957-11-19|   1|         0|       000|0302050027|      2|2022-06-09|2022-06-09|      Z501|      null|    null|    null|     M|   350790|        4|   64|        0|    0|    null|   null|    null|2081784|   05|             5|        01|s3a://datalake/so...|              SP|    2022|  false|                null|[{2022-07-09, Rev...|                30|        São Paulo|        São Paulo|                  Brotas|                  Brotas|                SP|                SP|         Sudeste|         Sudeste|                        21580|                        21580|                          1101.384|                          1101.384|
# |0006e299-d097-44d...|      05| null|15194004000125|   292740|1950-09-04|   3|         0|       000|0202010287|      1|2022-05-04|2022-05-04|       I10|      null|    null|    null|     M|   292740|        4|   71|        0|    0|    null|   null|    null|5407591|   06|             6|        01|s3a://datalake/so...|              BA|    2022|  false|                null|[{2022-04-15, Sex...|                 3|            Bahia|            Bahia|                Salvador|                Salvador|                BA|                BA|        Nordeste|        Nordeste|                      2675656|                      2675656|                           693.276|                           693.276|
# |a6b37b05-432c-4fa...|      06| null|78614971000208|   411370|2002-03-26|   1|         0|         0|0408060000|      1|2022-06-13|2022-06-13|       A90|      null|    null|    null|     M|   411370|        4|   20|        0|    0|    null|   null|    null|2577704|   06|             6|        01|s3a://datalake/so...|              PR|    2022|  false|                null|[{2022-06-24, Sag...|                 3|           Paraná|           Paraná|                Londrina|                Londrina|                PR|                PR|             Sul|             Sul|                       506701|                       506701|                          1653.075|                          1653.075|
# |000724d1-68aa-492...|      03| null|03284505000113|   230190|2011-02-14|   3|         0|       000|0403050022|      1|2022-03-16|2022-03-16|      G501|      null|    null|    null|     M|   230190|        4|   11|        0|    0|    null|   null|    null|2564211|   06|             6|        01|s3a://datalake/so...|              CE|    2022|  false|                null|[{2022-03-25, Dat...|                 9|            Ceará|            Ceará|                Barbalha|                Barbalha|                CE|                CE|        Nordeste|        Nordeste|                        55323|                        55323|                           569.508|                           569.508|
# |a6b4a087-24b8-416...|      03| null|47192752000165|   355030|1977-10-05|   1|         0|       000|0301060002|      1|2022-03-14|2022-03-14|      H521|      null|    null|    null|     M|   355030|        4|   44|        0|    0|    null|   null|    null|3119122|   01|             1|        01|s3a://datalake/so...|              SP|    2022|  false|                null|[{2022-03-02, Qua...|              null|        São Paulo|        São Paulo|               São Paulo|               São Paulo|                SP|                SP|         Sudeste|         Sudeste|                     11253503|                     11253503|                          1521.101|                          1521.101|
# |00098150-8fd5-4a2...|      10| null|92815000000834|   430920|2012-04-23|   3|         0|       000|0301060002|      1|2022-10-10|2022-10-10|      J019|      null|      18|    null|     M|   430920|        4|   10|        0|    0|    null|   null|    null|2232049|   01|00000000000000|        01|s3a://datalake/so...|              RS|    2022|  false|                null|[{2022-09-20, Pro...|                 2|Rio Grande do Sul|Rio Grande do Sul|                Gravataí|                Gravataí|                RS|                RS|             Sul|             Sul|                       255660|                       255660|                           463.499|                           463.499|
# |a6b4c2be-97b0-494...|      11| null|10892164000124|   261160|1986-04-14|   1|         0|       000|0301060002|      1|2022-11-20|2022-11-20|      S925|      null|      18|    null|     D|   261160|        4|   36|        0|    0|    null|   null|    null|0001120|   01|00000000000000|        01|s3a://datalake/so...|              PE|    2022|  false|[{Consciência Neg...|[{2022-12-08, Dia...|                 5|       Pernambuco|       Pernambuco|                  Recife|                  Recife|                PE|                PE|        Nordeste|        Nordeste|                      1537704|                      1537704|                           218.435|                           218.435|
# |000a1312-c494-41b...|      12| null|06288135000261|   150553|1990-04-03|   3|         0|       000|0202030679|      1|2022-12-21|2022-12-21|      Z000|      null|    null|    null|     M|   150553|        4|   32|        0|    0|    null|   null|    null|2614553|   01|             1|        01|s3a://datalake/so...|              PA|    2022|  false|                null|[{2023-01-20, Fer...|                 4|             Pará|             Pará|             Parauapebas|             Parauapebas|                PA|                PA|           Norte|           Norte|                       153908|                       153908|                          6886.208|                          6886.208|
# |a6b4cf05-ea59-4d6...|      09| null|60975174000363|   355030|1945-06-24|   3|         0|       000|0302050027|      1|2022-09-06|2022-09-06|      A300|      null|      18|    null|     M|   355030|        4|   77|        0|    0|    null|   null|    null|2080796|   01|00000000000000|        01|s3a://datalake/so...|              SP|    2022|  false|                null|[{2022-09-07, Ind...|                 1|        São Paulo|        São Paulo|               São Paulo|               São Paulo|                SP|                SP|         Sudeste|         Sudeste|                     11253503|                     11253503|                          1521.101|                          1521.101|
# |000c5910-eb57-4a6...|      05| null|60499365000215|   352050|1964-04-16|   1|         0|       000|0206030010|      1|2022-05-07|2022-05-07|       C64|       C64|    null|    null|     M|   352050|        4|   58|        0|    0|    null|   null|    null|2784602|   01|             1|        01|s3a://datalake/so...|              SP|    2022|  false|                null|[{2022-04-15, Sex...|                 6|        São Paulo|        São Paulo|              Indaiatuba|              Indaiatuba|                SP|                SP|         Sudeste|         Sudeste|                       201619|                       201619|                           312.049|                           312.049|
# |a6b6bfdf-e8a9-4f9...|      01| null|92815000000834|   430920|1970-02-26|   3|         0|       000|0301040001|      1|2022-01-11|2022-01-11|      G560|      null|    null|    null|     M|   430920|        4|   51|        0|    0|    null|   null|    null|2232049|   01|             1|        01|s3a://datalake/so...|              RS|    2022|  false|                null|[{2021-12-25, Nat...|                10|Rio Grande do Sul|Rio Grande do Sul|                Gravataí|                Gravataí|                RS|                RS|             Sul|             Sul|                       255660|                       255660|                           463.499|                           463.499|
# +--------------------+--------+-----+--------------+---------+----------+----+----------+----------+----------+-------+----------+----------+----------+----------+--------+--------+------+---------+---------+-----+---------+-----+--------+-------+--------+-------+-----+--------------+----------+--------------------+----------------+--------+-------+--------------------+--------------------+------------------+-----------------+-----------------+------------------------+------------------------+------------------+------------------+----------------+----------------+-----------------------------+-----------------------------+----------------------------------+----------------------------------+
# only showing top 20 rows

# %%
cid10 = spark.table("stage.cid10_joined")
cid10.show(truncate=False)
# Out:
# +-------------+---------------------------+----------------+-----------+--------------------------------------------------------------------------------------------+-------------------------------------------------+------------------------+-----------------------+---------+-----------------------+------------------------------------------------------------------------------------------------+--------------------------------------------------+--------------------+---------------+------------------------------------------------------------+--------------------------------------------------+
# |sub_categoria|sub_categoria_classificacao|restringido_sexo|causa_obito|sub_categoria_descricao                                                                     |sub_categoria_descricao_abreviada                |sub_categoria_referencia|sub_categoria_excluidos|categoria|categoria_classificacao|categoria_descricao                                                                             |categoria_descricao_abreviada                     |categoria_referencia|capitulo_numero|capitulo_descricao                                          |capitulo_descricao_abreviada                      |
# +-------------+---------------------------+----------------+-----------+--------------------------------------------------------------------------------------------+-------------------------------------------------+------------------------+-----------------------+---------+-----------------------+------------------------------------------------------------------------------------------------+--------------------------------------------------+--------------------+---------------+------------------------------------------------------------+--------------------------------------------------+
# |A288         |null                       |null            |null       |Outras doenças bacterianas zoonóticas especificadas não classificadas em outra parte        |A28.8 Outr doenc bacter zoonoticas espec NCOP    |null                    |null                   |A28      |null                   |Outras doenças bacterianas zoonóticas não classificadas em outra parte                          |A28   Outr doenc bacter zoonoticas NCOP           |null                |1              |Capítulo I - Algumas doenças infecciosas e parasitárias     |I.   Algumas doenças infecciosas e parasitárias   |
# |A982         |null                       |null            |null       |Doença da floresta de Kyasanur                                                              |A98.2 Doenc da floresta de Kyasanur              |null                    |null                   |A98      |null                   |Outras febres hemorrágicas por vírus, não classificadas em outra parte                          |A98   Outr febres hemorragicas p/virus NCOP       |null                |1              |Capítulo I - Algumas doenças infecciosas e parasitárias     |I.   Algumas doenças infecciosas e parasitárias   |
# |B022         |+                          |null            |null       |Herpes zoster acompanhado de outras manifestações neurológicas                              |B02.2 Herpes zoster acomp outr manif neurologicas|null                    |null                   |B02      |null                   |Herpes zoster [Zona]                                                                            |B02   Herpes zoster                               |null                |1              |Capítulo I - Algumas doenças infecciosas e parasitárias     |I.   Algumas doenças infecciosas e parasitárias   |
# |B400         |null                       |null            |null       |Blastomicose pulmonar aguda                                                                 |B40.0 Blastomicose pulmonar aguda                |null                    |null                   |B40      |null                   |Blastomicose                                                                                    |B40   Blastomicose                                |null                |1              |Capítulo I - Algumas doenças infecciosas e parasitárias     |I.   Algumas doenças infecciosas e parasitárias   |
# |C154         |null                       |null            |null       |Neoplasia maligna do terço médio do esôfago                                                 |C15.4 Terco medio do esofago                     |null                    |null                   |C15      |null                   |Neoplasia maligna do esôfago                                                                    |C15   Neopl malig do esofago                      |null                |2              |Capítulo II - Neoplasias [tumores]                          |II.  Neoplasias (tumores)                         |
# |C185         |null                       |null            |null       |Neoplasia maligna da flexura (ângulo) esplênica(o)                                          |C18.5 Flexura esplenica                          |null                    |null                   |C18      |null                   |Neoplasia maligna do cólon                                                                      |C18   Neopl malig do colon                        |null                |2              |Capítulo II - Neoplasias [tumores]                          |II.  Neoplasias (tumores)                         |
# |C480         |null                       |null            |null       |Neoplasia maligna do retroperitônio                                                         |C48.0 Retroperitonio                             |null                    |null                   |C48      |null                   |Neoplasia maligna dos tecidos moles do retroperitônio e do peritônio                            |C48   Neopl malig tec moles retro- e peritonio    |null                |2              |Capítulo II - Neoplasias [tumores]                          |II.  Neoplasias (tumores)                         |
# |C778         |null                       |null            |null       |Neoplasia maligna secundária e não especificada dos gânglios linfáticos de múltiplas regiões|C77.8 Ganglios linfaticos de mult regioes        |null                    |null                   |C77      |null                   |Neoplasia maligna secundária e não especificada dos gânglios linfáticos                         |C77   Neopl malig secund e NE gangl linfaticos    |null                |2              |Capítulo II - Neoplasias [tumores]                          |II.  Neoplasias (tumores)                         |
# |D091         |null                       |null            |null       |Carcinoma in situ de outros órgãos urinários e os não especificados                         |D09.1 Outr orgaos urinarios e os NE              |null                    |null                   |D09      |null                   |Carcinoma in situ de outras localizações e das não especificadas                                |D09   Carcinoma in situ de outr localiz e das NE  |null                |2              |Capítulo II - Neoplasias [tumores]                          |II.  Neoplasias (tumores)                         |
# |D093         |null                       |null            |null       |Carcinoma in situ da tireóide e de outras glândulas endócrinas                              |D09.3 Tireoide e de outr gland endocrinas        |null                    |null                   |D09      |null                   |Carcinoma in situ de outras localizações e das não especificadas                                |D09   Carcinoma in situ de outr localiz e das NE  |null                |2              |Capítulo II - Neoplasias [tumores]                          |II.  Neoplasias (tumores)                         |
# |D237         |null                       |null            |null       |Neoplasia benigna da pele dos membros inferiores, incluindo o quadril                       |D23.7 Pele dos membros infer incl o quadril      |null                    |null                   |D23      |null                   |Outras neoplasias benignas da pele                                                              |D23   Outr neopl benig da pele                    |null                |2              |Capítulo II - Neoplasias [tumores]                          |II.  Neoplasias (tumores)                         |
# |D251         |null                       |F               |null       |Leiomioma intramural do útero                                                               |D25.1 Leiomioma intramural do utero              |null                    |null                   |D25      |null                   |Leiomioma do útero                                                                              |D25   Leiomioma do utero                          |null                |2              |Capítulo II - Neoplasias [tumores]                          |II.  Neoplasias (tumores)                         |
# |E002         |null                       |null            |null       |Síndrome da deficiência congênita de iodo do tipo misto                                     |E00.2 Sindr defic congen iodo tipo misto         |null                    |null                   |E00      |null                   |Síndrome de deficiência congênita de iodo                                                       |E00   Sindr de defic congen de iodo               |null                |4              |Capítulo IV - Doenças endócrinas, nutricionais e metabólicas|IV.  Doenças endócrinas nutricionais e metabólicas|
# |E763         |null                       |null            |null       |Mucopolissacaridose não especificada                                                        |E76.3 Mucopolissacaridose NE                     |null                    |null                   |E76      |null                   |Distúrbios do metabolismo do glicosaminoglicano                                                 |E76   Disturbios metabolismo do glicosaminoglicano|null                |4              |Capítulo IV - Doenças endócrinas, nutricionais e metabólicas|IV.  Doenças endócrinas nutricionais e metabólicas|
# |E791         |null                       |null            |null       |Síndrome de Lesch-Nyhan                                                                     |E79.1 Sindr de Lesch-Nyhan                       |null                    |null                   |E79      |null                   |Distúrbios do metabolismo de purina e pirimidina                                                |E79   Disturbios metabolismo purina e pirimidina  |null                |4              |Capítulo IV - Doenças endócrinas, nutricionais e metabólicas|IV.  Doenças endócrinas nutricionais e metabólicas|
# |F072         |null                       |null            |null       |Síndrome pós-traumática                                                                     |F07.2 Sindr pos-traum                            |null                    |null                   |F07      |null                   |Transtornos de personalidade e do comportamento devidos a doença, a lesão e a disfunção cerebral|F07   Transt pers comport dev doen lesao disf cer |null                |5              |Capítulo V - Transtornos mentais e comportamentais          |V.   Transtornos mentais e comportamentais        |
# |F413         |null                       |null            |null       |Outros transtornos ansiosos mistos                                                          |F41.3 Outr transt ansiosos mistos                |null                    |null                   |F41      |null                   |Outros transtornos ansiosos                                                                     |F41   Outr transt ansiosos                        |null                |5              |Capítulo V - Transtornos mentais e comportamentais          |V.   Transtornos mentais e comportamentais        |
# |F419         |null                       |null            |null       |Transtorno ansioso não especificado                                                         |F41.9 Transt ansioso NE                          |null                    |null                   |F41      |null                   |Outros transtornos ansiosos                                                                     |F41   Outr transt ansiosos                        |null                |5              |Capítulo V - Transtornos mentais e comportamentais          |V.   Transtornos mentais e comportamentais        |
# |H268         |null                       |null            |N          |Outras cataratas especificadas                                                              |H26.8 Outr cataratas espec                       |null                    |null                   |H26      |null                   |Outras cataratas                                                                                |H26   Outr cataratas                              |null                |7              |Capítulo VII - Doenças do olho e anexos                     |VII. Doenças do olho e anexos                     |
# |K050         |null                       |null            |N          |Gengivite aguda                                                                             |K05.0 Gengivite aguda                            |null                    |null                   |K05      |null                   |Gengivite e doenças periodontais                                                                |K05   Gengivite e doenc periodontais              |null                |11             |Capítulo XI - Doenças do aparelho digestivo                 |XI.  Doenças do aparelho digestivo                |
# +-------------+---------------------------+----------------+-----------+--------------------------------------------------------------------------------------------+-------------------------------------------------+------------------------+-----------------------+---------+-----------------------+------------------------------------------------------------------------------------------------+--------------------------------------------------+--------------------+---------------+------------------------------------------------------------+--------------------------------------------------+
# only showing top 20 rows

# %%
ciha_step1.columns
# Out:
# ['pk',
#  'mes_cmpt',
#  'espec',
#  'cgc_hosp',
#  'munic_res',
#  'nasc',
#  'sexo',
#  'uti_mes_to',
#  'uti_int_to',
#  'proc_rea',
#  'qt_proc',
#  'dt_atend',
#  'dt_saida',
#  'diag_princ',
#  'diag_secun',
#  'cobranca',
#  'natureza',
#  'gestao',
#  'munic_mov',
#  'cod_idade',
#  'idade',
#  'dias_perm',
#  'morte',
#  'nacional',
#  'car_int',
#  'homonimo',
#  'cnes',
#  'fonte',
#  'cgc_consor',
#  'modalidade',
#  'input_file_name',
#  'arquivo_sigla_uf',
#  'ano_cmpt',
#  'feriado',
#  'feriados',
#  'feriados_prox',
#  'feriados_prox_dist',
#  'munic_res_nome_uf',
#  'munic_mov_nome_uf',
#  'munic_res_nome_municipio',
#  'munic_mov_nome_municipio',
#  'munic_res_sigla_uf',
#  'munic_mov_sigla_uf',
#  'munic_res_regiao',
#  'munic_mov_regiao',
#  'munic_res_populacao_residente',
#  'munic_mov_populacao_residente',
#  'munic_res_area_unidade_territorial',
#  'munic_mov_area_unidade_territorial']

# %%
ciha_step2 = (ciha_step1.alias("s1")
    .join(cid10.alias("cid10_princ"),
          col("s1.diag_princ") == col("cid10_princ.sub_categoria"),
         "left")
    .join(cid10.alias("cid10_secun"),
          col("s1.diag_secun") == col("cid10_secun.sub_categoria"),
         "left")
    .select(
        col("s1.pk"),
        col("s1.mes_cmpt"),
        col("s1.espec"),
        col("s1.cgc_hosp"),
        col("s1.munic_res"),
        col("s1.nasc"),
        col("s1.sexo"),
        col("s1.uti_mes_to"),
        col("s1.uti_int_to"),
        col("s1.proc_rea"),
        col("s1.qt_proc"),
        col("s1.dt_atend"),
        dayofweek('s1.dt_atend').alias("dt_atend_dow"),
        col("s1.dt_saida"),
        col("s1.diag_princ"),
        col("s1.diag_secun"),
        col("s1.cobranca"),
        col("s1.natureza"),
        col("s1.gestao"),
        col("s1.munic_mov"),
        col("s1.cod_idade"),
        col("s1.idade"),
        col("s1.dias_perm"),
        col("s1.morte"),
        col("s1.nacional"),
        col("s1.car_int"),
        col("s1.homonimo"),
        col("s1.cnes"),
        col("s1.fonte"),
        col("s1.cgc_consor"),
        col("s1.modalidade"),
        col("s1.input_file_name"),
        col("s1.arquivo_sigla_uf"),
        col("s1.ano_cmpt"),
        col("s1.feriado"),
        col("s1.feriados"),
        col("s1.feriados_prox"),
        col("s1.feriados_prox_dist"),
        col("s1.munic_res_nome_uf"),
        col("s1.munic_mov_nome_uf"),
        col("s1.munic_res_nome_municipio"),
        col("s1.munic_mov_nome_municipio"),
        col("s1.munic_res_sigla_uf"),
        col("s1.munic_mov_sigla_uf"),
        col("s1.munic_res_regiao"),
        col("s1.munic_mov_regiao"),
        col("s1.munic_res_populacao_residente"),
        col("s1.munic_mov_populacao_residente"),
        col("s1.munic_res_area_unidade_territorial"),
        col("s1.munic_mov_area_unidade_territorial"),
        struct("cid10_princ.*").alias("diag_princ_cid10"),
        struct("cid10_secun.*").alias("diag_secun_cid10")
    )
)
    
ciha_step2.printSchema()
ciha_step2.show(truncate=False)
# Out:
# root
#  |-- pk: string (nullable = true)
#  |-- mes_cmpt: string (nullable = true)
#  |-- espec: string (nullable = true)
#  |-- cgc_hosp: string (nullable = true)
#  |-- munic_res: string (nullable = true)
#  |-- nasc: date (nullable = true)
#  |-- sexo: string (nullable = true)
#  |-- uti_mes_to: string (nullable = true)
#  |-- uti_int_to: string (nullable = true)
#  |-- proc_rea: string (nullable = true)
#  |-- qt_proc: string (nullable = true)
#  |-- dt_atend: date (nullable = true)
#  |-- dt_atend_dow: integer (nullable = true)
#  |-- dt_saida: date (nullable = true)
#  |-- diag_princ: string (nullable = true)
#  |-- diag_secun: string (nullable = true)
#  |-- cobranca: string (nullable = true)
#  |-- natureza: string (nullable = true)
#  |-- gestao: string (nullable = true)
#  |-- munic_mov: string (nullable = true)
#  |-- cod_idade: string (nullable = true)
#  |-- idade: string (nullable = true)
#  |-- dias_perm: string (nullable = true)
#  |-- morte: string (nullable = true)
#  |-- nacional: string (nullable = true)
#  |-- car_int: string (nullable = true)
#  |-- homonimo: string (nullable = true)
#  |-- cnes: string (nullable = true)
#  |-- fonte: string (nullable = true)
#  |-- cgc_consor: string (nullable = true)
#  |-- modalidade: string (nullable = true)
#  |-- input_file_name: string (nullable = true)
#  |-- arquivo_sigla_uf: string (nullable = true)
#  |-- ano_cmpt: integer (nullable = true)
#  |-- feriado: boolean (nullable = true)
#  |-- feriados: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- nome: string (nullable = true)
#  |    |    |-- tipo: string (nullable = true)
#  |    |    |-- descricao: string (nullable = true)
#  |    |    |-- uf: string (nullable = true)
#  |    |    |-- municipio: string (nullable = true)
#  |-- feriados_prox: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- data: string (nullable = true)
#  |    |    |-- nome: string (nullable = true)
#  |    |    |-- tipo: string (nullable = true)
#  |    |    |-- descricao: string (nullable = true)
#  |    |    |-- uf: string (nullable = true)
#  |    |    |-- municipio: string (nullable = true)
#  |-- feriados_prox_dist: integer (nullable = true)
#  |-- munic_res_nome_uf: string (nullable = true)
#  |-- munic_mov_nome_uf: string (nullable = true)
#  |-- munic_res_nome_municipio: string (nullable = true)
#  |-- munic_mov_nome_municipio: string (nullable = true)
#  |-- munic_res_sigla_uf: string (nullable = true)
#  |-- munic_mov_sigla_uf: string (nullable = true)
#  |-- munic_res_regiao: string (nullable = true)
#  |-- munic_mov_regiao: string (nullable = true)
#  |-- munic_res_populacao_residente: string (nullable = true)
#  |-- munic_mov_populacao_residente: string (nullable = true)
#  |-- munic_res_area_unidade_territorial: string (nullable = true)
#  |-- munic_mov_area_unidade_territorial: string (nullable = true)
#  |-- diag_princ_cid10: struct (nullable = false)
#  |    |-- sub_categoria: string (nullable = true)
#  |    |-- sub_categoria_classificacao: string (nullable = true)
#  |    |-- restringido_sexo: string (nullable = true)
#  |    |-- causa_obito: string (nullable = true)
#  |    |-- sub_categoria_descricao: string (nullable = true)
#  |    |-- sub_categoria_descricao_abreviada: string (nullable = true)
#  |    |-- sub_categoria_referencia: string (nullable = true)
#  |    |-- sub_categoria_excluidos: string (nullable = true)
#  |    |-- categoria: string (nullable = true)
#  |    |-- categoria_classificacao: string (nullable = true)
#  |    |-- categoria_descricao: string (nullable = true)
#  |    |-- categoria_descricao_abreviada: string (nullable = true)
#  |    |-- categoria_referencia: string (nullable = true)
#  |    |-- capitulo_numero: string (nullable = true)
#  |    |-- capitulo_descricao: string (nullable = true)
#  |    |-- capitulo_descricao_abreviada: string (nullable = true)
#  |-- diag_secun_cid10: struct (nullable = false)
#  |    |-- sub_categoria: string (nullable = true)
#  |    |-- sub_categoria_classificacao: string (nullable = true)
#  |    |-- restringido_sexo: string (nullable = true)
#  |    |-- causa_obito: string (nullable = true)
#  |    |-- sub_categoria_descricao: string (nullable = true)
#  |    |-- sub_categoria_descricao_abreviada: string (nullable = true)
#  |    |-- sub_categoria_referencia: string (nullable = true)
#  |    |-- sub_categoria_excluidos: string (nullable = true)
#  |    |-- categoria: string (nullable = true)
#  |    |-- categoria_classificacao: string (nullable = true)
#  |    |-- categoria_descricao: string (nullable = true)
#  |    |-- categoria_descricao_abreviada: string (nullable = true)
#  |    |-- categoria_referencia: string (nullable = true)
#  |    |-- capitulo_numero: string (nullable = true)
#  |    |-- capitulo_descricao: string (nullable = true)
#  |    |-- capitulo_descricao_abreviada: string (nullable = true)
#
# +------------------------------------+--------+-----+--------------+---------+----------+----+----------+----------+----------+-------+----------+------------+----------+----------+----------+--------+--------+------+---------+---------+-----+---------+-----+--------+-------+--------+-------+-----+--------------+----------+---------------------------------------------+----------------+--------+-------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+-----------------+-----------------+------------------------+------------------------+------------------+------------------+----------------+----------------+-----------------------------+-----------------------------+----------------------------------+----------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |pk                                  |mes_cmpt|espec|cgc_hosp      |munic_res|nasc      |sexo|uti_mes_to|uti_int_to|proc_rea  |qt_proc|dt_atend  |dt_atend_dow|dt_saida  |diag_princ|diag_secun|cobranca|natureza|gestao|munic_mov|cod_idade|idade|dias_perm|morte|nacional|car_int|homonimo|cnes   |fonte|cgc_consor    |modalidade|input_file_name                              |arquivo_sigla_uf|ano_cmpt|feriado|feriados                                                                                                                                                                                                                                                                                    |feriados_prox                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |feriados_prox_dist|munic_res_nome_uf|munic_mov_nome_uf|munic_res_nome_municipio|munic_mov_nome_municipio|munic_res_sigla_uf|munic_mov_sigla_uf|munic_res_regiao|munic_mov_regiao|munic_res_populacao_residente|munic_mov_populacao_residente|munic_res_area_unidade_territorial|munic_mov_area_unidade_territorial|diag_princ_cid10                                                                                                                                                                                                                                                                                                                                                                                                       |diag_secun_cid10                                                                                                                                                                                                                                                                         ...
# +------------------------------------+--------+-----+--------------+---------+----------+----+----------+----------+----------+-------+----------+------------+----------+----------+----------+--------+--------+------+---------+---------+-----+---------+-----+--------+-------+--------+-------+-----+--------------+----------+---------------------------------------------+----------------+--------+-------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+-----------------+-----------------+------------------------+------------------------+------------------+------------------+----------------+----------------+-----------------------------+-----------------------------+----------------------------------+----------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |00016e53-72d5-47ab-b88b-9e6d1d203e27|08      |null |60552098000111|355030   |1972-06-26|3   |0         |000       |0301010072|2      |2022-08-23|3           |2022-08-23|E039      |null      |null    |null    |M     |355030   |4        |50   |0        |0    |null    |null   |null    |2082624|01   |1             |01        |s3a://datalake/source/ciha_csv/CIHASP2208.csv|SP              |2022    |false  |null                                                                                                                                                                                                                                                                                        |[{2022-07-26, Fundação da Cidade de Goiás, FACULTATIVO, Feriado para Servidores Públicos. Determinado pelo Estatuto dos Funcionários Públicos Civis do Estado de Goiás e de suas Autarquias, Lei nº 10.460, de 22 de fevereiro de 1988, null, null}, {2022-09-07, Independência do Brasil, NACIONAL, O Dia da Indepência do Brasil, oficialmente a data comemorada é a de 7 de setembro de 1822, em que ocorreu o chamado "Grito do Ipiranga"., null, null}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |15                |São Paulo        |São Paulo        |São Paulo               |São Paulo               |SP                |SP                |Sudeste         |Sudeste         |11253503                     |11253503                     |1521.101                          |1521.101                          |{E039, null, null, null, Hipotireoidismo não especificado, E03.9 Hipotireoidismo NE, null, null, E03, null, Outros hipotireoidismos, E03   Outr hipotireoidismos, null, 4, Capítulo IV - Doenças endócrinas, nutricionais e metabólicas, IV.  Doenças endócrinas nutricionais e metabólicas}                                                                                                                           |{null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null}                                                                                                                                                                                         ...
# |a6ad9b39-44dd-468e-ba1e-392bea26a397|01      |null |20959292000100|313170   |1992-01-14|3   |0         |000       |0301010072|1      |2022-01-19|4           |2022-01-19|R529      |null      |18      |null    |M     |313170   |4        |30   |0        |0    |null    |null   |null    |2215586|01   |00000000000000|01        |s3a://datalake/source/ciha_csv/CIHAMG2201.csv|MG              |2022    |false  |null                                                                                                                                                                                                                                                                                        |[{2021-12-25, Natal, NACIONAL, O Natal é comemorado anualmente em 25 de Dezembro. Originalmente destinado a celebrar o nascimento anual do Deus Sol no solstício de inverno, foi adaptado pela Igreja Católica no 3o século d.C., para permitir a conversão dos povos pagãos sob o domínio do Império Romano, passando a comemorar o nascimento de Jesus de Nazaré., null, null}, {2022-01-01, Ano Novo, NACIONAL, O Ano-Novo ou Réveillon é um evento que acontece quando uma cultura celebra o fim de um ano e o começo do próximo. A celebração do evento é também chamada Réveillon, termo oriundo do verbo francês réveiller, que em português significa DESPERTAR, null, null}, {2021-12-31, Após o meio-dia, Véspera de Ano Novo, FACULTATIVO, De acordo com o Decreto nº 18882-E de 01 de junho de 2015, null, null}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |18                |Minas Gerais     |Minas Gerais     |Itabira                 |Itabira                 |MG                |MG                |Sudeste         |Sudeste         |109783                       |109783                       |1253.704                          |1253.704                          |{R529, null, null, null, Dor não especificada, R52.9 Dor NE, null, null, R52, null, Dor não classificada em outra parte, R52   Dor NCOP, null, 18, Capítulo XVIII - Sintomas, sinais e achados anormais de exames clínicos e de laboratório, não classificados em outra parte, XVIII.Sint sinais e achad anorm ex clín e laborat}                                                                                      |{null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null}                                                                                                                                                                                         ...
# |0001aa82-4139-476b-9866-c8bb53e508a3|04      |null |61599908000158|355030   |1965-02-01|1   |0         |000       |0407010009|2      |2022-04-22|6           |2022-04-22|Z018      |null      |null    |null    |M     |355030   |4        |57   |0        |0    |null    |null   |null    |2080575|01   |1             |01        |s3a://datalake/source/ciha_csv/CIHASP2204.csv|SP              |2022    |false  |null                                                                                                                                                                                                                                                                                        |[{2022-04-15, Sexta-feira Santa, MUNICIPAL, conforme Lei nº 14.485 de 19 de julho de 2007, SP, São Paulo }, {2022-04-15, Sexta-Feira Santa, NACIONAL, Também chamada de "Sexta Feira da Paixão" é a sexta-feira que ocorre antes do domingo de Páscoa, e é o dia que os cristãos lembram da crucificação de Cristo., null, null}, {2022-03-29, Aniversário da Ciadade, FACULTATIVO, Fundação de Curitiba - Aniversário da Cidade (Ponto Facultativo), conforme Lei Municipal nº229,26/12/49, null, null}, {2022-04-21, Dia de Tiradentes, NACIONAL, Joaquim José da Silva Xavier, o Tiradentes foi um dentista, tropeiro, minerador, comerciante, militar e ativista político. É reconhecido como mártir da Inconfidência Mineira e herói nacional. O dia de sua execução, 21 de abril, é feriado nacional., null, null}, {2022-05-01, Dia do Trabalho, NACIONAL, O Dia do Trabalhador ou Dia Internacional dos Trabalhadores é celebrado anualmente no dia 1º de Maio em numerosos países do mundo, sendo feriado no Brasil, em Portugal e em outros países., null, null}, {2022-04-14, Quinta-feira santa, FACULTATIVO, null, null, null}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |1                 |São Paulo        |São Paulo        |São Paulo               |São Paulo               |SP                |SP                |Sudeste         |Sudeste         |11253503                     |11253503                     |1521.101                          |1521.101                          |{Z018, null, null, null, Outros exames especiais especificados, Z01.8 Outr exames especiais espec, null, null, Z01, null, Outros exames e investigações especiais de pessoas sem queixa ou diagnóstico relatado, Z01   Outr exam invest esp pess s/queix diag relat, null, 21, Capítulo XXI - Fatores que influenciam o estado de saúde e o contato com os serviços de saúde, XXI. Contatos com serviços de saúde}     |{null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null}                                                                                                                                                                                         ...
# |a6b09c4e-c80a-433e-bf94-e3b48f0fa668|03      |null |60975737008560|355030   |1965-03-01|3   |0         |000       |0301060061|1      |2022-03-31|5           |2022-03-31|Z00       |null      |null    |null    |M     |355030   |4        |57   |0        |0    |null    |null   |null    |9406751|01   |1             |01        |s3a://datalake/source/ciha_csv/CIHASP2203.csv|SP              |2022    |false  |null                                                                                                                                                                                                                                                                                        |[{2022-04-15, Sexta-feira Santa, MUNICIPAL, conforme Lei nº 14.485 de 19 de julho de 2007, SP, São Paulo }, {2022-03-02, Quarta Feira de Cinzas, FACULTATIVO, Ponto Facultativo nas repartições públicas, null, null}, {2022-03-19, Dia de São José, FACULTATIVO, Padroeiro do Estado do Ceará, null, null}, {2022-03-01, Carnaval, FACULTATIVO, Carnaval NÃO é um feriado oficial, é Ponto Facultativo, ou seja, cabe às empresas e orgão públicos decidirem se trabalharão ou não., null, null}, {2022-04-15, Sexta-Feira Santa, NACIONAL, Também chamada de "Sexta Feira da Paixão" é a sexta-feira que ocorre antes do domingo de Páscoa, e é o dia que os cristãos lembram da crucificação de Cristo., null, null}, {2022-03-29, Aniversário da Ciadade, FACULTATIVO, Fundação de Curitiba - Aniversário da Cidade (Ponto Facultativo), conforme Lei Municipal nº229,26/12/49, null, null}, {2022-03-02, Carnaval, FACULTATIVO, Ponto Facultativo até às 14h., null, null}, {2022-04-21, Dia de Tiradentes, NACIONAL, Joaquim José da Silva Xavier, o Tiradentes foi um dentista, tropeiro, minerador, comerciante, militar e ativista político. É reconhecido como mártir da Inconfidência Mineira e herói nacional. O dia de sua execução, 21 de abril, é feriado nacional., null, null}, {2022-03-01, Terça de Carnaval, FACULTATIVO, Feriado apenas no Comércio, segundo Lei nº 5913, de 21 de junho de 1991, null, null}, {2022-03-19, São José, FACULTATIVO, Dia de São José padroeiro de Mafra, null, null}, {2022-04-14, Quinta-feira santa, FACULTATIVO, null, null, null}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |15                |São Paulo        |São Paulo        |São Paulo               |São Paulo               |SP                |SP                |Sudeste         |Sudeste         |11253503                     |11253503                     |1521.101                          |1521.101                          |{null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null}                                                                                                                                                                                                                                                                                                                       |{null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null}                                                                                                                                                                                         ...
# |00031bdc-881a-4fd8-a16a-c7c7901fb460|09      |null |09152345000135|315120   |1980-03-23|3   |0         |000       |0301060061|1      |2022-09-19|2           |2022-09-19|E669      |null      |null    |null    |M     |315120   |4        |42   |0        |0    |null    |null   |null    |2119528|01   |1             |01        |s3a://datalake/source/ciha_csv/CIHAMG2209.csv|MG              |2022    |false  |null                                                                                                                                                                                                                                                                                        |[{2022-10-12, Nossa Senhora Aparecida, NACIONAL, Nossa Senhora da Conceição Aparecida é a padroeira do Brasil. Sua festa é celebrada em 12 de outubro, um feriado nacional desde que o Papa João Paulo II consagrou a Basílica em 1980., null, null}, {2022-09-07, Independência do Brasil, NACIONAL, O Dia da Indepência do Brasil, oficialmente a data comemorada é a de 7 de setembro de 1822, em que ocorreu o chamado "Grito do Ipiranga"., null, null}, {2022-10-15, Dia do Professor, FACULTATIVO, FERIADO ESCOLAR - No dia 15 de outubro de 1827 (dia consagrado à educadora Santa Teresa de Ávila), o Imperador do Brasil, Pedro I, baixou um Decreto Imperial que criou o Ensino Elementar no Brasil. Pelo decreto, "todas as cidades, vilas e lugarejos teriam suas escolas de primeiras letras", null, null}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |12                |Minas Gerais     |Minas Gerais     |Pirapora                |Pirapora                |MG                |MG                |Sudeste         |Sudeste         |53368                        |53368                        |549.514                           |549.514                           |{E669, null, null, null, Obesidade não especificada, E66.9 Obesidade NE, null, null, E66, null, Obesidade, E66   Obesidade, null, 4, Capítulo IV - Doenças endócrinas, nutricionais e metabólicas, IV.  Doenças endócrinas nutricionais e metabólicas}                                                                                                                                                                 |{null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null}                                                                                                                                                                                         ...
# |a6b189ba-f2b3-4a81-a7d7-fc8141101b22|03      |null |60194990000844|310620   |1944-06-27|3   |0         |001       |0408030003|1      |2022-03-23|4           |2022-03-27|M511      |null      |12      |null    |M     |310620   |4        |77   |4        |0    |null    |null   |null    |2200422|01   |1             |02        |s3a://datalake/source/ciha_csv/CIHAMG2203.csv|MG              |2022    |false  |null                                                                                                                                                                                                                                                                                        |[{2022-04-15, Sexta-feira Santa, MUNICIPAL, conforme Lei nº 1327, de 08 de fevereiro de 1967, MG, Belo Horizonte }, {2022-03-02, Quarta Feira de Cinzas, FACULTATIVO, Ponto Facultativo nas repartições públicas, null, null}, {2022-03-19, Dia de São José, FACULTATIVO, Padroeiro do Estado do Ceará, null, null}, {2022-02-28, Facultativo, FACULTATIVO, aniversário de morte de José Pedro Dias, fundador de Juara, null, null}, {2022-03-01, Carnaval, FACULTATIVO, Carnaval NÃO é um feriado oficial, é Ponto Facultativo, ou seja, cabe às empresas e orgão públicos decidirem se trabalharão ou não., null, null}, {2022-02-28, Segunda de Carnaval, FACULTATIVO, Ponto Facultativo nas repartições públicas, null, null}, {2022-04-15, Sexta-Feira Santa, NACIONAL, Também chamada de "Sexta Feira da Paixão" é a sexta-feira que ocorre antes do domingo de Páscoa, e é o dia que os cristãos lembram da crucificação de Cristo., null, null}, {2022-03-29, Aniversário da Ciadade, FACULTATIVO, Fundação de Curitiba - Aniversário da Cidade (Ponto Facultativo), conforme Lei Municipal nº229,26/12/49, null, null}, {2022-02-28, Carnaval, FACULTATIVO, Ponto Facultativo, ou seja, cabe às empresas e orgão públicos decidirem se trabalharão ou não., null, null}, {2022-03-02, Carnaval, FACULTATIVO, Ponto Facultativo até às 14h., null, null}, {2022-04-21, Dia de Tiradentes, NACIONAL, Joaquim José da Silva Xavier, o Tiradentes foi um dentista, tropeiro, minerador, comerciante, militar e ativista político. É reconhecido como mártir da Inconfidência Mineira e herói nacional. O dia de sua execução, 21 de abril, é feriado nacional., null, null}, {2022-03-01, Terça de Carnaval, FACULTATIVO, Feriado apenas no Comércio, segundo Lei nº 5913, de 21 de junho de 1991, null, null}, {2022-03-19, São José, FACULTATIVO, Dia de São José padroeiro de Mafra, null, null}, {2022-04-14, Quinta-feira santa, FACULTATIVO, null, null, null}]                                                                                                                                                                                                                                                                                                                                                                                                                                |23                |Minas Gerais     |Minas Gerais     |Belo Horizonte          |Belo Horizonte          |MG                |MG                |Sudeste         |Sudeste         |2375151                      |2375151                      |331.401                           |331.401                           |{M511, +, null, null, Transtornos de discos lombares e de outros discos intervertebrais com radiculopatia, M51.1 Transt disco lombar outr intervert radiculop, G55.1*, null, M51, null, Outros transtornos de discos intervertebrais, M51   Outr transt de discos intervertebrais, null, 13, Capítulo XIII - Doenças do sistema osteomuscular e do tecido conjuntivo, XIII.Doenças sist osteomuscular e tec conjuntivo}|{null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null}                                                                                                                                                                                         ...
# |0004b978-4ac7-4ab6-a2b3-8eb76cc3119d|11      |null |10892164000124|261160   |1959-11-17|3   |0         |000       |0301060002|1      |2022-11-29|3           |2022-11-29|B342      |null      |18      |null    |D     |261160   |4        |63   |0        |0    |null    |null   |null    |0001120|01   |00000000000000|01        |s3a://datalake/source/ciha_csv/CIHAPE2211.csv|PE              |2022    |false  |null                                                                                                                                                                                                                                                                                        |[{2022-12-08, Dia de Nossa Senhora da Conceição, MUNICIPAL, conforme a Lei nº 9.777 de junho de 1967, PE, Recife }, {2022-12-08, Dia da Imaculada Conceição, FACULTATIVO, Dia da Imaculada Conceição, padroeira da cidade, null, null}, {2022-11-20, Dia da Consciência Negra, FACULTATIVO, Lei Municipal No 1985, de 2009. Prefeitura não funcionará. O Comércio deverá Funcionar normalmente, null, null}, {2022-10-31, Dia do Evangélico, FACULTATIVO, Dia do Evangélico, null, null}, {2022-12-08, Ponto Facultativo, FACULTATIVO, Nossa Senhora da Conceição, null, null}, {2022-11-15, Proclamação da República, NACIONAL, A Proclamação da República foi um levante político-militar ocorrido em 15 de novembro de 1889 que instaurou a forma Republicana Federativa Presidencialista de governo no Brasil, derrubando a Monarquia e, por conseguinte, o imperador dom Pedro II., null, null}, {2022-11-02, Dia de Finados, NACIONAL, O Dia de Finados ou Dia dos Fiéis Defuntos, (conhecido ainda como Dia dos Mortos no México), é celebrado pela Igreja Católica no dia 2 de novembro e é Feriado Nacional., null, null}, {2022-11-18, Tratado de Petrópolis, FACULTATIVO, Feriado no dia 17de Novembro, segundo a lei Nº 57/1965, mas adiado para próxima Sexta-Feira. O atual estado brasileiro do Acre era, no início do século XX, uma região pertencente à Bolívia e foi incorporado ao Brasil pelo Barão do Rio Branco através do Tratado de Petrópolis, firmado em 17 de novembro de 1903., null, null}, {2022-12-08, N. Sra. da Conceição, FACULTATIVO, Nossa Senhora da Conceição, null, null}, {2022-11-20, Consciência Negra, FACULTATIVO, Dia da Consciência Negra. Ponto Facultativo de acordo com a Lei Municipal 2484/2008, null, null}, {2022-12-25, Natal, NACIONAL, O Natal é comemorado anualmente em 25 de Dezembro. Originalmente destinado a celebrar o nascimento anual do Deus Sol no solstício de inverno, foi adaptado pela Igreja Católica no 3o século d.C., para permitir a conversão dos povos pagãos sob o domínio do Império Romano, passando a comemorar o nascimento de Jesus de Nazaré., null, null}]                                                                                                                                                                                                                                                        |9                 |Pernambuco       |Pernambuco       |Recife                  |Recife                  |PE                |PE                |Nordeste        |Nordeste        |1537704                      |1537704                      |218.435                           |218.435                           |{B342, null, null, null, Infecção por coronavírus de localização não especificada, B34.2 Infecc p/coronavirus localiz NE, null, null, B34, null, Doenças por vírus, de localização não especificada, B34   Doenc p/virus de localiz NE, null, 1, Capítulo I - Algumas doenças infecciosas e parasitárias, I.   Algumas doenças infecciosas e parasitárias}                                                             |{null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null}                                                                                                                                                                                         ...
# ...
# |000c5910-eb57-4a6a-892d-416271da4c9c|05      |null |60499365000215|352050   |1964-04-16|1   |0         |000       |0206030010|1      |2022-05-07|7           |2022-05-07|C64       |C64       |null    |null    |M     |352050   |4        |58   |0        |0    |null    |null   |null    |2784602|01   |1             |01        |s3a://datalake/source/ciha_csv/CIHASP2205.csv|SP              |2022    |false  |null                                                                                                                                                                                                                                                                                        |[{2022-04-15, Sexta-Feira Santa, NACIONAL, Também chamada de "Sexta Feira da Paixão" é a sexta-feira que ocorre antes do domingo de Páscoa, e é o dia que os cristãos lembram da crucificação de Cristo., null, null}, {2022-04-21, Dia de Tiradentes, NACIONAL, Joaquim José da Silva Xavier, o Tiradentes foi um dentista, tropeiro, minerador, comerciante, militar e ativista político. É reconhecido como mártir da Inconfidência Mineira e herói nacional. O dia de sua execução, 21 de abril, é feriado nacional., null, null}, {2022-05-01, Dia do Trabalho, NACIONAL, O Dia do Trabalhador ou Dia Internacional dos Trabalhadores é celebrado anualmente no dia 1º de Maio em numerosos países do mundo, sendo feriado no Brasil, em Portugal e em outros países., null, null}, {2022-04-14, Quinta-feira santa, FACULTATIVO, null, null, null}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |6                 |São Paulo        |São Paulo        |Indaiatuba              |Indaiatuba              |SP                |SP                |Sudeste         |Sudeste         |201619                       |201619                       |312.049                           |312.049                           |{C64, null, null, null, Neoplasia maligna do rim, exceto pelve renal, C64   Neopl malig do rim exceto pelve renal, null, null, C64, null, Neoplasia maligna do rim, exceto pelve renal, C64   Neopl malig do rim exceto pelve renal, null, 2, Capítulo II - Neoplasias [tumores], II.  Neoplasias (tumores)}                                                                                                           |{C64, null, null, null, Neoplasia maligna do rim, exceto pelve renal, C64   Neopl malig do rim exceto pelve renal, null, null, C64, null, Neoplasia maligna do rim, exceto pelve renal, C64   Neopl malig do rim exceto pelve renal, null, 2, Capítulo II - Neoplasias [tumores], II.  N ...
# |a6b6bfdf-e8a9-4f9b-9cdb-0b63c779ae92|01      |null |92815000000834|430920   |1970-02-26|3   |0         |000       |0301040001|1      |2022-01-11|3           |2022-01-11|G560      |null      |null    |null    |M     |430920   |4        |51   |0        |0    |null    |null   |null    |2232049|01   |1             |01        |s3a://datalake/source/ciha_csv/CIHARS2201.csv|RS              |2022    |false  |null                                                                                                                                                                                                                                                                                        |[{2021-12-25, Natal, NACIONAL, O Natal é comemorado anualmente em 25 de Dezembro. Originalmente destinado a celebrar o nascimento anual do Deus Sol no solstício de inverno, foi adaptado pela Igreja Católica no 3o século d.C., para permitir a conversão dos povos pagãos sob o domínio do Império Romano, passando a comemorar o nascimento de Jesus de Nazaré., null, null}, {2022-01-01, Ano Novo, NACIONAL, O Ano-Novo ou Réveillon é um evento que acontece quando uma cultura celebra o fim de um ano e o começo do próximo. A celebração do evento é também chamada Réveillon, termo oriundo do verbo francês réveiller, que em português significa DESPERTAR, null, null}, {2021-12-31, Após o meio-dia, Véspera de Ano Novo, FACULTATIVO, De acordo com o Decreto nº 18882-E de 01 de junho de 2015, null, null}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |10                |Rio Grande do Sul|Rio Grande do Sul|Gravataí                |Gravataí                |RS                |RS                |Sul             |Sul             |255660                       |255660                       |463.499                           |463.499                           |{G560, null, null, N, Síndrome do túnel do carpo, G56.0 Sindr do tunel do carpo, null, null, G56, null, Mononeuropatias dos membros superiores, G56   Mononeuropatias dos membros super, null, 6, Capítulo VI - Doenças do sistema nervoso, VI.  Doenças do sistema nervoso}                                                                                                                                           |{null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null}                                                                                                                                                                                         ...
# +------------------------------------+--------+-----+--------------+---------+----------+----+----------+----------+----------+-------+----------+------------+----------+----------+----------+--------+--------+------+---------+---------+-----+---------+-----+--------+-------+--------+-------+-----+--------------+----------+---------------------------------------------+----------------+--------+-------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+-----------------+-----------------+------------------------+------------------------+------------------+------------------+----------------+----------------+-----------------------------+-----------------------------+----------------------------------+----------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 20 rows

# %%
spark.sql("drop table stage.ciha_step2")
# Out:
# ++
# ||
# ++
# ++

# %%
DeltaTable.createIfNotExists(spark) \
  .tableName("stage.ciha_step2") \
  .addColumns(ciha_step2.schema) \
  .partitionedBy("ano_cmpt") \
  .execute()

# %%
spark.sql("delete from stage.ciha_step2")
# Out:
# +-----------------+
# |num_affected_rows|
# +-----------------+
# |        117092917|
# +-----------------+

# %%
ciha_step2.write.mode("overwrite").insertInto("stage.ciha_step2")

# %%
spark.sql("optimize stage.ciha_step2")
# Out:
# +--------------------+--------------------+
# |                path|             metrics|
# +--------------------+--------------------+
# |s3a://datalake/st...|{16, 88, {2394364...|
# +--------------------+--------------------+

# %%
spark.conf.set("spark.databricks.delta.retentionDurationCheck.enabled", "false")

# %%
spark.sql("VACUUM stage.ciha_step2 RETAIN 0 HOURS")
# Out:
# +--------------------+
# |                path|
# +--------------------+
# |s3a://datalake/st...|
# +--------------------+

# %%
spark.stop()

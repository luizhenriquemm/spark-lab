# %%
# !pip install faker
# Out:
# Collecting faker
#   Obtaining dependency information for faker from https://files.pythonhosted.org/packages/64/ec/ebab37789278e91ddc39fe357e68d14613f3d0a299f393eed990b92f75a4/Faker-20.0.3-py3-none-any.whl.metadata
#   Downloading Faker-20.0.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.4 in /opt/conda/lib/python3.11/site-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Downloading Faker-20.0.3-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 14.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: faker
# Successfully installed faker-20.0.3

# %%
import requests, time, random, json, datetime
from faker import Faker

last_client_id = 10
last_product_id = 10

# %%
products = ["V-Neck T-Shirt","Hoodie","Hoodie with Logo","T-Shirt","Beanie",
    "Belt","Cap","Sunglasses","Hoodie with Pocket","Hoodie with Zipper",
    "Long Sleeve Tee","Polo","Album","Single","V-Neck T-Shirt - Red","V-Neck T-Shirt - Green",
    "V-Neck T-Shirt - Blue","Hoodie - Red, No","Hoodie - Green, No",
    "Hoodie - Blue, No","T-Shirt with Logo","Beanie with Logo",
    "Logo Collection","WordPress Pennant","Hoodie - Blue, Yes"]

for

# %%
def random_birthdate():
    min_age = 18 * 365
    max_age = 75 * 365
    days = random.randint(min_age, max_age)
    birthdate = (datetime.datetime.today() - datetime.timedelta(days=days)).strftime("%Y-%m-%d")
    return birthdate

def do_client():
    url = "http://app-server:5000/api/cadastro/novo"
    fake=Faker()
    payload = json.dumps({
      "name": fake.name(),
      "gender": random.choice(['Male', 'Female', 'Not Informed']),
      "birthdate": random_birthdate(),
      "address": fake.street_address() + ' | ' + fake.city() + ' | ' + fake.country_code(),
      "city": fake.city(),
      "state": fake.state()
    })
    headers = {'Content-Type': 'application/json'}
    response = requests.request("POST", url, headers=headers, data=payload)
    last_client_id = response.json()["client_id"]
    return response.status_code

def do_product():
    url = "http://app-server:5000/api/produto/novo"
    fake=Faker()
    payload = json.dumps({
      "name": fake.name(),
      "value": random.choice(['Male', 'Female', 'Not Informed']),
      "catgory_id": 1
    })
    headers = {'Content-Type': 'application/json'}
    response = requests.request("POST", url, headers=headers, data=payload)
    last_client_id = response.json()["client_id"]
    return response.status_code

# %%
for i in range(10):
    random.choices([0,1,2])
# Out:
# {
#   "r": {
#     "address": "79593 Mary Manors Apt. 706 | Nicoleton | BN",
#     "birthdate": "2000-01-01",
#     "city": "Port Jennifer",
#     "client_id": 107,
#     "gender": "Female",
#     "name": "Margaret King",
#     "state": "Iowa"
#   },
#   "status_code": 200
# }
#
# {
#   "r": {
#     "address": "52627 Ryan Island | New Devonbury | CY",
#     "birthdate": "2000-01-01",
#     "city": "Nguyenfort",
#     "client_id": 108,
#     "gender": "Male",
#     "name": "Mrs. Brittany Orr MD",
#     "state": "New York"
#   },
#   "status_code": 200
# }
#
# {
#   "r": {
#     "address": "35291 Corey Ford Suite 306 | Meghanside | AM",
#     "birthdate": "2000-01-01",
#     "city": "Velazquezhaven",
#     "client_id": 109,
#     "gender": "Male",
#     "name": "Dave Stewart",
#     "state": "North Carolina"
#   },
#   "status_code": 200
# }
#
# {
#   "r": {
#     "address": "892 Brittany Extensions | North Michael | QA",
#     "birthdate": "2000-01-01",
#     "city": "East Matthewbury",
#     "client_id": 110,
#     "gender": "Male",
#     "name": "Justin Pierce",
#     "state": "Michigan"
#   },
#   "status_code": 200
# }
#
# {
#   "r": {
#     "address": "31561 Kimberly Trail Suite 150 | East Williamborough | BY",
#     "birthdate": "2000-01-01",
#     "city": "Port Elizabeth",
#     "client_id": 111,
#     "gender": "Female",
#     "name": "Logan Miller",
#     "state": "Maine"
#   },
#   "status_code": 200
# }
#
# {
#   "r": {
#     "address": "4120 Davis Knolls | Connerstad | SG",
#     "birthdate": "2000-01-01",
#     "city": "North Sharonmouth",
#     "client_id": 112,
#     "gender": "Not Informed",
#     "name": "Mrs. Megan Pena MD",
#     "state": "Minnesota"
#   },
#   "status_code": 200
# }
#
# {
#   "r": {
#     "address": "840 Jackson Fort | Smithtown | DZ",
#     "birthdate": "2000-01-01",
#     "city": "North Amy",
#     "client_id": 113,
#     "gender": "Not Informed",
#     "name": "Jacob Miles",
#     "state": "North Carolina"
#   },
#   "status_code": 200
# }
#
# {
#   "r": {
#     "address": "957 Angel Station Suite 642 | Amandatown | IQ",
#     "birthdate": "2000-01-01",
#     "city": "Meghanhaven",
#     "client_id": 114,
#     "gender": "Not Informed",
#     "name": "Bridget Carrillo",
#     "state": "Alabama"
#   },
#   "status_code": 200
# }
#
# {
#   "r": {
#     "address": "599 Wright Stream | Lake Jessica | BD",
#     "birthdate": "2000-01-01",
#     "city": "Port Davidchester",
#     "client_id": 115,
#     "gender": "Female",
#     "name": "Daniel Conley",
#     "state": "Texas"
#   },
#   "status_code": 200
# }
#
# {
#   "r": {
#     "address": "1521 Bridges Center | Joyton | CY",
#     "birthdate": "2000-01-01",
#     "city": "Port Josephhaven",
#     "client_id": 116,
#     "gender": "Female",
#     "name": "Dawn Bell",
#     "state": "Utah"
#   },
#   "status_code": 200
# }
